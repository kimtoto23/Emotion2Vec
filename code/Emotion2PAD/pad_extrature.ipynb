# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/SER_0817/EMODB_cnn_lstm/PAD_mapping.xlsx')
df
# Out:
#          TERM_K                           TERM   N  P_MEAN  P_SD  A_MEAN  \
# 0           용감한                          Bold  NaN     NaN   NaN     NaN
# 1           유용한                        Useful  NaN     NaN   NaN     NaN
# 2           거대한                        Mighty  NaN     NaN   NaN     NaN
# 3           친절한                          Kind  NaN     NaN   NaN     NaN
# 4         자기 만족                Self-satisfied  NaN     NaN   NaN     NaN
# 5            감탄                       Admired  NaN     NaN   NaN     NaN
# 6         자랑스러운                         Proud  NaN     NaN   NaN     NaN
# 7         관심 있는                    Interested  NaN     NaN   NaN     NaN
# 8           오만한                      Arrogant  NaN     NaN   NaN     NaN
# 9           탁월한                      Inspired  NaN     NaN   NaN     NaN
# 10          흥분한                       Excited  NaN     NaN   NaN     NaN
# 11         힘 있는                   Influential  NaN     NaN   NaN     NaN
# ...

# %%
texture = []
with open("/content/drive/MyDrive/SER_0817/EMODB_cnn_lstm/ser_PAD_text_file/ser_PAD.txt", 'r')as f:
  for line in f:
    texture.append(line.strip())

# %%
for i in range(len(texture)):
  df.iloc[i,2] = int((texture[i].split())[0])
  df.iloc[i,3] = float((texture[i].split())[1])
  df.iloc[i,4] = float((texture[i].split())[2])

# %%
texture = []
with open("/content/drive/MyDrive/SER_0817/EMODB_cnn_lstm/ser_PAD_2.txt", 'r')as f:
  for line in f:
    texture.append(line.strip())

# %%
for i in range(44):
  df.iloc[i,5] = float((texture[i].split())[0])
  df.iloc[i,6] = float((texture[i].split())[1])
  #df.iloc[i,4] = float((texture[i].split())[2])

  df.iloc[i,7] = float((texture[45+i].split())[0])
  df.iloc[i,8] = float((texture[45+i].split())[1])
  #df.iloc[i,4] = float((texture[i].split())[2])

# %%
texture = []
with open("/content/drive/MyDrive/SER_0817/EMODB_cnn_lstm/ser_PAD_3.txt", 'r')as f:
  for line in f:
    texture.append(line.strip())

# %%
for i in range(47):
  df.iloc[i+44,2] = int((texture[i].split())[0])
  df.iloc[i+44,3] = float((texture[i+48].split())[0])
  #df.iloc[i,4] = float((texture[i].split())[2])

  # df.iloc[i,7] = float((texture[45+i].split())[0])
  # df.iloc[i,8] = float((texture[45+i].split())[1])
  #df.iloc[i,4] = float((texture[i].split())[2])

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# pd.options.display.max_rows = 60
# pd.options.display.max_columns = 20

# %%
df
# Out:
#          TERM_K                           TERM     N  P_MEAN  P_SD  A_MEAN  \
# 0           용감한                          Bold   27.0    0.44  0.32    0.61
# 1           유용한                        Useful   27.0    0.70  0.20    0.44
# 2           거대한                        Mighty   27.0    0.48  0.37    0.51
# 3           친절한                          Kind   27.0    0.73  0.22    0.19
# 4         자기 만족                Self-satisfied   27.0    0.86  0.10    0.20
# 5            감탄                       Admired   29.0    0.81  0.21    0.44
# 6         자랑스러운                         Proud   29.0    0.77  0.21    0.38
# 7         관심 있는                    Interested   29.0    0.64  0.20    0.51
# 8           오만한                      Arrogant   29.0    0.00  0.51    0.34
# 9           탁월한                      Inspired   29.0    0.71  0.30    0.63
# 10          흥분한                       Excited   29.0    0.62  0.25    0.75
# ...

# %%
texture = []
with open("/content/drive/MyDrive/SER_0817/EMODB_cnn_lstm/ser_PAD_4.txt", 'r')as f:
  for line in f:
    texture.append(line.strip())

# %%
texture
# Out:
# ['0.39 0.13 0.29 -0.08 0.49',
#  '0.26 0.07 0.30 -0.14 0.35',
#  '0.17 0.54 0.26 -0.18 0.30',
#  '0.23 0.16 0.22 -0.21 0.34',
#  '0.17 0.65 0.24 -0.05 0.37',
#  '0.45 0.59 0.31 -0.15 0.32',
#  '0.26 0.30 0.25 -0.32 0.34',
#  '0.30 0.67 0.27 -0.13 0.38',
#  '0.26 0.62 0.20 -0.01 0.43',
#  '0.37 0.24 0.35 -0.17 0.26',
#  '0.22 0.51 0.23 -0.07 0.35',
#  '0.34 0.40 0.30 -0.38 0.21',
#  '0.39 0.45 0.34 -0.24 0.32',
#  '0.30 0.62 0.20 -0.01 0.34',
#  '0.30 -0.46 0.38 0.06 0.49',
#  '0.25 -0.01 0.46 0.33 0.39',
#  '0.34 -0.06 0.30 0.12 0.39',
#  '0.22 -0.13 0.32 0.03 0.37',
#  '0.35 -0.25 0.31 0.11 0.33',
#  '0.35 -0.01 0.30 0.25 0.32',
#  '0.35 -0.32 0.33 0.11 0.33',
#  '0.37 -0.19 0.28 0.02 0.37',
#  '0.35 -0.22 0.37 -0.42 0.40',
#  '0.50 -0.19 0.33 -0.28 0.38',
#  '0.57 -0.40 0.21 -0.04 0.39',
#  '0.43 -0.36 0.32 -0.44 0.24',
#  '0.39 -0.28 0.24 -0.27 0.35',
#  '0.39 -0.32 0.26 -0.11 0.33',
#  '0.35 -0.08 0.26 -0.29 0.34',
#  '0.26 0.88 0.19 -0.15 0.26',
#  '0.20 0.35 0.41 0.11 0.34',
# ...

# %%
for i in range(47):
  df.iloc[i+44,4] = float((texture[i].split())[0])
  df.iloc[i+44,5] = float((texture[i].split())[1])
  df.iloc[i+44,6] = float((texture[i].split())[2])
  df.iloc[i+44,7] = float((texture[i].split())[3])
  df.iloc[i+44,8] = float((texture[i].split())[4])

# %%
texture = []
with open("/content/drive/MyDrive/SER_0817/EMODB_cnn_lstm/ser_PAD_5.txt", 'r')as f:
  for line in f:
    texture.append(line.strip())

# %%
texture
# Out:
# ['30 -0.08 0.41',
#  '30 -0.43 0.29',
#  '30 -0.24 0.31',
#  '27 -0.69 0.50',
#  '27 -0.64 0.18',
#  '27 -0.61 0.17',
#  '27 -0.57 0.34',
#  '27 -0.63 0.18',
#  '29 -0.44 0.26',
#  '29 -0.64 0.20',
#  '29 -0.62 0.20',
#  '27 -0.37 0.24',
#  '29 -0.71 0.18',
#  '28 -0.63 0.16',
#  '28 -0.09 0.34',
#  '29 -0.50 0.30',
#  '29 -0.57 0.33',
#  '29 -0.55 0.21',
#  '29 -0.46 0.30',
#  '30 -0.63 0.20',
#  '30 -0.61 0.24',
#  '29 -0.58 0.21',
#  '26 -0.28 0.35',
#  '25 -0.06 0.35',
#  '28 -0.30 0.36',
#  '29 -0.15 0.33',
#  '29 -0.57 0.19',
#  '30 -0.27 0.34',
#  '30 -0.42 0.22',
#  '30 -0.53 0.20',
#  '30 -0.50 0.22',
#  '30 -0.52 0.24',
#  '30 -0.33 0.35',
#  '25 -0.32 0.32',
#  '27 -0.72 0.21',
#  '27 -0.72 0.21',
#  '29 -0.66 0.35',
#  '29 -0.19 0.58',
#  '29 -0.66 0.2l',
#  '28 -0.15 0.41',
#  '28 -0.65 0.19',
#  '29 -0.42 0.35',
#  '29 -0.6l 0.25',
#  '30 -0.54 0.26',
#  '30 -0.18 0.48',
#  '29 -0.62 0.24',
#  '29 -0.17 0.35']

# %%
for i in range(47):
  df.iloc[i+91,2] = int((texture[i].split())[0])
  df.iloc[i+91,3] = float((texture[i].split())[1])
  df.iloc[i+91,4] = float((texture[i].split())[2])
  # df.iloc[i+44,7] = float((texture[i].split())[3])
  # df.iloc[i+44,8] = float((texture[i].split())[4])

# %%
texture = []
with open("/content/drive/MyDrive/SER_0817/EMODB_cnn_lstm/ser_PAD_6.txt", 'r')as f:
  for line in f:
    texture.append(line.strip())

# %%
for i in range(47):
  df.iloc[i+91,5] = float((texture[i].split())[0])
  df.iloc[i+91,6] = float((texture[i].split())[1])
  df.iloc[i+91,7] = float((texture[i].split())[2])
  df.iloc[i+91,8] = float((texture[i].split())[3])
  # df.iloc[i+44,8] = float((texture[i].split())[4])

# %%
texture = []
with open("/content/drive/MyDrive/SER_0817/EMODB_cnn_lstm/ser_PAD_7.txt", 'r')as f:
  for line in f:
    texture.append(line.strip())

# %%
texture
# Out:
# ['30 -0.53 0.35 -0.13 0.40 -0.29 0.32',
#  '16 -0.45 0.39 -0.43 0.36 -0.17 0.42',
#  '26 -0.29 0.33 -0.51 0.25 -0.16 0.30',
#  '27 -0.47 0.28 -0.24 0.34 -0.13 0.26',
#  '27 -0.45 0.41 -0.59 0.28 -0.24 0.28',
#  '28 -0.46 0.32 -0.43 0.41 -0.46 0.27',
#  '29 -0.18 0.38 -0.33 0.42 -0.24 0.35',
#  '30 -0.62 0.26 -0.19 0.34 -0.14 0.28',
#  '30 -0.41 0.26 -0.50 0.22 -0.08 0.24',
#  '30 -0.31 0.34 -0.26 0.28 -0.14 0.29',
#  '30 -0.53 0.19 -0.16 0.41 -0.26 0.30',
#  '30 -0.61 0.25 -0.15 0.32 -0.29 0.32',
#  '30 -0.63 0.23 -0.27 0.34 -0.33 0.22']

# %%
for i in range(13):
  df.iloc[i+138,2] = float((texture[i].split())[0])
  df.iloc[i+138,3] = float((texture[i].split())[1])
  df.iloc[i+138,4] = float((texture[i].split())[2])
  df.iloc[i+138,5] = float((texture[i].split())[3])
  df.iloc[i+138,6] = float((texture[i].split())[4])
  df.iloc[i+138,7] = float((texture[i].split())[5])
  df.iloc[i+138,8] = float((texture[i].split())[6])
  # df.iloc[i+44,8] = float((texture[i].split())[4])

# %%
df
# Out:
#          TERM_K                           TERM     N  P_MEAN  P_SD  A_MEAN  \
# 0           용감한                          Bold   27.0    0.44  0.32    0.61
# 1           유용한                        Useful   27.0    0.70  0.20    0.44
# 2           거대한                        Mighty   27.0    0.48  0.37    0.51
# 3           친절한                          Kind   27.0    0.73  0.22    0.19
# 4         자기 만족                Self-satisfied   27.0    0.86  0.10    0.20
# 5            감탄                       Admired   29.0    0.81  0.21    0.44
# 6         자랑스러운                         Proud   29.0    0.77  0.21    0.38
# 7         관심 있는                    Interested   29.0    0.64  0.20    0.51
# 8           오만한                      Arrogant   29.0    0.00  0.51    0.34
# 9           탁월한                      Inspired   29.0    0.71  0.30    0.63
# 10          흥분한                       Excited   29.0    0.62  0.25    0.75
# ...

# %%
df.to_csv('/content/drive/MyDrive/SER_0817/EMODB_cnn_lstm/SER_PAD.csv')
